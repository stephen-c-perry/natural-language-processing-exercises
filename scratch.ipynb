# %% [markdown]
# Scratch notepad for exploring instructor's functions

# %%
import acquire as a
import prepare as p
import explore as e

# %%
blog = a.get_blog_articles_data()

# %%
p.basic_clean('We went to the park!')
# Out:
# 'we went to the park'

# %%
sentence= 'We went to the park!  We had a lot of fun'

p.tokenize(sentence)
# Out:
# 'We went to the park ! We had a lot of fun'

# %%
sentence = p.basic_clean(sentence)
sentence
# Out:
# 'we went to the park  we had a lot of fun'

# %%
senetence = p.tokenize(sentence)
sentence
# Out:
# 'we went to the park  we had a lot of fun'

# %%
sentence2 = 'We went walking at the park'

p.stem(sentence2)
# Out:
# 'we went walk at the park'

# %%
p.lemmatize(sentence)
# Out:
# 'we went to the park we had a lot of fun'

# %%
articles = a.get_news_articles_data()

# %%
articles
# Out:
#                                                  title  \
# 0    Case filed against Gauri Khan in UP's Lucknow ...
# 1    Messi buys 35 gold iPhones worth ₹1.7 cr for W...
# 2    It was mayhem: Mark Waugh on Indore pitch for ...
# 3    Asked him for tips, he said 'At the end of the...
# 4    Mockery of Test cricket: Dilip Vengsarkar on I...
# ..                                                 ...
# 295  Bengaluru's Rapid Road project put on hold ove...
# 296  Bombay HC uploading Marathi translations of ju...
# 297  Tragic human error caused Greece's worst train...
# 298  India's metal exports to be hurt by EU's carbo...
# 299  Alphabet's Waymo cuts 137 jobs to 'focus on co...
#
#                                                content    category
# 0    An FIR has been filed against Gauri Khan and o...    national
# 1    Argentina footballer Lionel Messi has reported...    national
# 2    Former Australia batter Mark Waugh criticised ...    national
# ...

# %%
p.prep_article_data(articles, 'title')
# Out:
#                                                  title  \
# 0    Case filed against Gauri Khan in UP's Lucknow ...
# 1    Messi buys 35 gold iPhones worth ₹1.7 cr for W...
# 2    It was mayhem: Mark Waugh on Indore pitch for ...
# 3    Asked him for tips, he said 'At the end of the...
# 4    Mockery of Test cricket: Dilip Vengsarkar on I...
# ..                                                 ...
# 295  Bengaluru's Rapid Road project put on hold ove...
# 296  Bombay HC uploading Marathi translations of ju...
# 297  Tragic human error caused Greece's worst train...
# 298  India's metal exports to be hurt by EU's carbo...
# 299  Alphabet's Waymo cuts 137 jobs to 'focus on co...
#
#                                               original  \
# 0    An FIR has been filed against Gauri Khan and o...
# 1    Argentina footballer Lionel Messi has reported...
# 2    Former Australia batter Mark Waugh criticised ...
# 3    Australia left-arm spinner Matthew Kuhnemann h...
# ...

# %%
p.prep_article_data(articles, 'category')
# Out:
#                                                  title  \
# 0    Case filed against Gauri Khan in UP's Lucknow ...
# 1    Messi buys 35 gold iPhones worth ₹1.7 cr for W...
# 2    It was mayhem: Mark Waugh on Indore pitch for ...
# 3    Asked him for tips, he said 'At the end of the...
# 4    Mockery of Test cricket: Dilip Vengsarkar on I...
# ..                                                 ...
# 295  Bengaluru's Rapid Road project put on hold ove...
# 296  Bombay HC uploading Marathi translations of ju...
# 297  Tragic human error caused Greece's worst train...
# 298  India's metal exports to be hurt by EU's carbo...
# 299  Alphabet's Waymo cuts 137 jobs to 'focus on co...
#
#                                               original       clean    stemmed  \
# 0    An FIR has been filed against Gauri Khan and o...    national     nation
# 1    Argentina footballer Lionel Messi has reported...    national     nation
# ...

# %%
p.prep_article_data(articles, 'content')
# Out:
#                                                  title  \
# 0    Case filed against Gauri Khan in UP's Lucknow ...
# 1    Messi buys 35 gold iPhones worth ₹1.7 cr for W...
# 2    It was mayhem: Mark Waugh on Indore pitch for ...
# 3    Asked him for tips, he said 'At the end of the...
# 4    Mockery of Test cricket: Dilip Vengsarkar on I...
# ..                                                 ...
# 295  Bengaluru's Rapid Road project put on hold ove...
# 296  Bombay HC uploading Marathi translations of ju...
# 297  Tragic human error caused Greece's worst train...
# 298  India's metal exports to be hurt by EU's carbo...
# 299  Alphabet's Waymo cuts 137 jobs to 'focus on co...
#
#                                               original  \
# 0    An FIR has been filed against Gauri Khan and o...
# 1    Argentina footballer Lionel Messi has reported...
# 2    Former Australia batter Mark Waugh criticised ...
# 3    Australia left-arm spinner Matthew Kuhnemann h...
# ...
